# %% [markdown]
# # Problem Statement:
# ##1}}The Iris dataset contains measurements of four features—sepal length, sepal width, petal length, and petal width—for three different species of iris flowers: Iris Setosa, Iris Versicolor, and Iris Virginica.
# 2}}The goal of this analysis is to use the K-Means clustering algorithm to segment the iris flowers into clusters based on these four features. The assumption is that similar measurements among flowers might indicate similarities in species, though this is an unsupervised analysis and the algorithm will work without using species labels.

# %% [markdown]
# # importing the library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import os
os.environ["OMP_NUM_THREADS"] = '1'

# %% [markdown]
# # Loading the data which is inbuilt in sklearn

# %%
iris = load_iris()
data_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
data_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data_iris.shape
# Out:
# (150, 4)

# %%
data_iris.isnull().sum()### Observation: There is no missing values.
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# # Data Preprocessing: normalise or standardize the data

# %% [markdown]
# # normalization

# %%
scaler =StandardScaler()
standard_data=scaler.fit_transform(data_iris)

# %% [markdown]
# # Visual and Statistical Understanding of data

# %%
data_iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
plt.scatter(data_iris['sepal length (cm)'],data_iris['sepal width (cm)'],color="blue",marker='.')
plt.xlabel("Sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.show()

# %%
plt.scatter(data_iris['petal length (cm)'],data_iris['petal width (cm)'],color="red",marker='.')
plt.xlabel("Petal length (cm)")
plt.ylabel("Petal width (cm)")
plt.show()

# %%
plt.scatter(data_iris['sepal length (cm)'],data_iris['petal length (cm)'],color="green",marker='.')
plt.xlabel("Sepal length (cm)")
plt.ylabel("Petal length (cm)")
plt.show()

# %%
plt.scatter(data_iris['sepal width (cm)'],data_iris['petal width (cm)'],color="violet",marker='*')
plt.xlabel("Sepal width (cm)")
plt.ylabel("Petal width (cm)")
plt.show()

# %%
plt.scatter(data_iris['sepal length (cm)'],data_iris['petal width (cm)'],color="red",marker='*')
plt.xlabel("Sepal length (cm)")
plt.ylabel("Petal width (cm)")
plt.show()

# %%
plt.scatter(data_iris['sepal width (cm)'],data_iris['petal length (cm)'],color="green",marker='*')
plt.xlabel("Sepal width (cm)")
plt.ylabel("Petal width (cm)")
plt.show()

# %%
inertia = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(standard_data)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 11), inertia, marker='o',color="red")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
# Out:
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
standard_data
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
normal= Normalizer()
normalizer_data = normal.fit_transform(data_iris)

# %%
normalizer_data
# Out:
# array([[0.80377277, 0.55160877, 0.22064351, 0.0315205 ],
#        [0.82813287, 0.50702013, 0.23660939, 0.03380134],
#        [0.80533308, 0.54831188, 0.2227517 , 0.03426949],
#        [0.80003025, 0.53915082, 0.26087943, 0.03478392],
#        [0.790965  , 0.5694948 , 0.2214702 , 0.0316386 ],
#        [0.78417499, 0.5663486 , 0.2468699 , 0.05808704],
#        [0.78010936, 0.57660257, 0.23742459, 0.0508767 ],
#        [0.80218492, 0.54548574, 0.24065548, 0.0320874 ],
#        [0.80642366, 0.5315065 , 0.25658935, 0.03665562],
#        [0.81803119, 0.51752994, 0.25041771, 0.01669451],
#        [0.80373519, 0.55070744, 0.22325977, 0.02976797],
#        [0.786991  , 0.55745196, 0.26233033, 0.03279129],
#        [0.82307218, 0.51442011, 0.24006272, 0.01714734],
#        [0.8025126 , 0.55989251, 0.20529392, 0.01866308],
#        [0.81120865, 0.55945424, 0.16783627, 0.02797271],
#        [0.77381111, 0.59732787, 0.2036345 , 0.05430253],
# ...

# %%
scaler
# Out:
# StandardScaler()

# %%
normal
# Out:
# Normalizer()

# %%
inertia = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(normalizer_data)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 11), inertia, marker='o',color="blue")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
# Out:
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Applying K-Means Clustering

# %%
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=0)
cluster_assignments = kmeans.fit_predict(normalized_data)
data['Cluster'] = cluster_assignments
# Out:
# C:\Users\SUHAS JADHAV\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(data['sepal length (cm)'], data['petal length (cm)'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Clustered Data')
plt.show()

# %%
plt.scatter(data['sepal length (cm)'], data['petal width (cm)'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Petal width')
plt.title('Clustered Data')
plt.show()

# %%
plt.scatter(data['petal length (cm)'], data['petal width (cm)'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.title('Clustered Data')
plt.show()

# %%
plt.scatter(data['sepal length (cm)'], data['sepal width (cm)'], c=data['Cluster'], cmap='viridis')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('Clustered Data')
plt.show()

# %%
plt.scatter(data['sepal width (cm)'], data['petal width (cm)'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Sepal width')
plt.ylabel('Petal width')
plt.title('Clustered Data')
plt.show()
